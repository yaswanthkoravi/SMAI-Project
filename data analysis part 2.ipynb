# %%
import numpy as np 
import pandas as kfp
import seaborn as sb

# %%
import plotly 
plotly.tools.set_credentials_file(username='starlord75', api_key='IsuzU0kStJADCk4UQo4T')
import plotly.plotly as py
import plotly.graph_objs as go

# %%
data = kfp.read_csv('new.csv')

# %%
data.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0       0    0   18        1        0        0     4     4     0     4
# 1       0    0   17        1        0        1     1     1     0     2
# 2       0    0   15        1        1        1     1     1     0     2
# 3       0    0   15        1        0        1     4     2     1     3
# 4       0    0   16        1        0        1     3     3     2     2
#
#     ...    internet  romantic  famrel  freetime  goout  Dalc  Walc  health  \
# 0   ...           0        no       4         3      4     1     1       3
# 1   ...           1        no       5         3      3     1     1       3
# 2   ...           1        no       4         3      2     2     3       3
# 3   ...           1       yes       3         2      2     1     1       5
# 4   ...           0        no       4         3      2     1     2       5
#
#    absences  passed
# 0         6       0
# 1         4       0
# 2        10       1
# ...

# %%
data.describe()
# Out:
#            school         sex         age     address     famsize     Pstatus  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.116456    0.473418   16.696203    0.777215    0.288608    0.896203
# std      0.321177    0.499926    1.276043    0.416643    0.453690    0.305384
# min      0.000000    0.000000   15.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   16.000000    1.000000    0.000000    1.000000
# 50%      0.000000    0.000000   17.000000    1.000000    0.000000    1.000000
# 75%      0.000000    1.000000   18.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000   22.000000    1.000000    1.000000    1.000000
#
#              Medu        Fedu        Mjob        Fjob     ...          higher  \
# count  395.000000  395.000000  395.000000  395.000000     ...      395.000000
# mean     2.749367    2.521519    2.169620    2.281013     ...        0.949367
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
len(data)
# Out:
# 395

# %%
data.shape
# Out:
# (395, 31)

# %%
data['passed'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# Name: passed, dtype: int64

# %%
# school1 = np.unique(data['school'])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
S= LabelEncoder()

# %%
school_labels = S.fit_transform(data['school'])

# %%
data['school']=school_labels

# %%
data['school'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: school, dtype: int64

# %%
passed_labels = S.fit_transform(data['passed'])

# %%
data['passed']=passed_labels

# %%
# sb.jointplot(x=data['school'],y=data['passed'], data=data, kind='reg')

# %%
sex_labels = S.fit_transform(data['sex'])

# %%
data['sex']=sex_labels

# %%
address_labels = S.fit_transform(data['address'])

# %%
data['address']=address_labels

# %%
famsize_labels = S.fit_transform(data['famsize'])

# %%
data['famsize']=famsize_labels

# %%
Pstatus_labels = S.fit_transform(data['Pstatus'])

# %%
data['Pstatus']=Pstatus_labels

# %%
Pstatus_labels = S.fit_transform(data['Pstatus'])

# %%
data['Pstatus']=Pstatus_labels

# %%
Mjob_labels = S.fit_transform(data['Mjob'])

# %%
data['Mjob']=Mjob_labels

# %%
Fjob_labels = S.fit_transform(data['Fjob'])

# %%
data['Fjob']=Fjob_labels

# %%
internet_labels = S.fit_transform(data['internet'])

# %%
data['internet']=internet_labels

# %%
reason_labels = S.fit_transform(data['reason'])

# %%
data['reason']=reason_labels

# %%
guardian_labels = S.fit_transform(data['guardian'])

# %%
data['guardian']=guardian_labels

# %%
schoolsup_labels = S.fit_transform(data['schoolsup'])

# %%
data['schoolsup']=schoolsup_labels

# %%
famsup_labels = S.fit_transform(data['famsup'])

# %%
data['famsup']=famsup_labels

# %%
paid_labels = S.fit_transform(data['paid'])

# %%
data['paid']=paid_labels

# %%
activities_labels = S.fit_transform(data['activities'])

# %%
data['activities']=activities_labels

# %%
nursery_labels = S.fit_transform(data['nursery'])

# %%
data['nursery']=nursery_labels

# %%
higher_labels = S.fit_transform(data['higher'])

# %%
data['higher']=higher_labels

# %%
romantic_labels = S.fit_transform(data['romantic'])

# %%
data['romantic']=romantic_labels

# %%
data.describe()
# Out:
#            school         sex         age     address     famsize     Pstatus  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.116456    0.473418   16.696203    0.777215    0.288608    0.896203
# std      0.321177    0.499926    1.276043    0.416643    0.453690    0.305384
# min      0.000000    0.000000   15.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   16.000000    1.000000    0.000000    1.000000
# 50%      0.000000    0.000000   17.000000    1.000000    0.000000    1.000000
# 75%      0.000000    1.000000   18.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000   22.000000    1.000000    1.000000    1.000000
#
#              Medu        Fedu        Mjob        Fjob     ...          higher  \
# count  395.000000  395.000000  395.000000  395.000000     ...      395.000000
# mean     2.749367    2.521519    2.169620    2.281013     ...        0.949367
# ...

# %% [markdown]
# School attribute has 2 different values. Correlation with dropping is there

# %%
sb.jointplot(x=data['school'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Males have a lower droput ratio than females

# %%
sb.jointplot(x=data['sex'],y=data['passed'], data=data, kind='reg')1a

# %% [markdown]
# There is a negative correlation b/w age and passed students

# %%
sb.jointplot(x=data['age'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Students living in address R fare better than the students living in address U

# %%
sb.jointplot(x=data['address'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Students living in larger families do better than the students living in smaller families

# %%
sb.jointplot(x=data['famsize'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['Pstatus'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Medu(Mothers education) is a ordinal variable. Has values 0,1,2,3,4. Higher value indicates better educated mother. As we can see mothers education is highly correlated with student passing

# %%
sb.jointplot(x=data['Medu'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Fedu(Fathers education) is a ordinal variable. Has values 0,1,2,3,4. Higher value indicates better educated father. As we can see fathers education is highly correlated with student passing

# %%
sb.jointplot(x=data['Fedu'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Mjob(Mothers job) is a ordinal variable. Has values 0,1,2,3,4. Higher value indicates mother working in a better job. As we can see mothers job is somewhat correlated with student passing

# %%
sb.jointplot(x=data['Mjob'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Fjob(Fathers job) is a ordinal variable. Has values 0,1,2,3,4. Higher value indicates father working in a better job. As we can see fathers job is somewhat correlated with student passing

# %%
sb.jointplot(x=data['Fjob'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['reason'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Students who dont have their mother or father as the guardian have a harder time and thus have higher dropout rate

# %%
sb.jointplot(x=data['guardian'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Students having higher travel time have higher dropout rate as expected

# %%
sb.jointplot(x=data['traveltime'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# As expected, students who study more tend to drop-out less.

# %%
sb.jointplot(x=data['studytime'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['failures'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['schoolsup'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['famsup'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['paid'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Participating in activities doesnt really correlate with a student dropping out

# %%
sb.jointplot(x=data['activities'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['nursery'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['higher'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Students having internet connection tend to drop-out less!

# %%
sb.jointplot(x=data['internet'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Students who are romantic tend to drop-out more!

# %%
sb.jointplot(x=data['romantic'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Ordinal variable. Higher value indicates better family relations. As, expected better familial relations correlate with students doing well.

# %%
sb.jointplot(x=data['famrel'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Free time doesnt correlate with dropping out.

# %%
sb.jointplot(x=data['freetime'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# goout is an ordinal variable. As can be seen from the graph, students who go out more are more likely to drop out!

# %%
sb.jointplot(x=data['goout'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['Dalc'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['Walc'],y=data['passed'], data=data, kind='reg')

# %%
sb.jointplot(x=data['health'],y=data['passed'], data=data, kind='reg')

# %% [markdown]
# Absent : number of times a student was absent. One of the most important variable which is most correlated with droppig out.

# %%
sb.jointplot(x=data['absences'],y=data['passed'], data=data, kind='reg')
